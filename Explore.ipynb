# %%
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
with open('data/means.pkl','rb') as f:
    mean = pickle.load(f)
    
mean_ser = pd.Series(np.array(mean).mean(0), index = mean[0].index)
swing_states = mean_ser.loc[['Florida','Michigan','Pennsylvania','Wisconsin']]
starts = ((swing_states-.5)*200).round(2)

# %%
#DAG MH
swings = [starts]
ecs = []
times = ['Day','7 PM','7:30 PM','8 PM','8:30 PM','9 PM','10 PM','Final']
for st in ['6.5','7.0','7.5','8.0','8.5','9.0','10.0','13.0']:
    with open('data/dag_MH_{}.pkl'.format(st), 'rb') as f:
        swing, ec = pickle.load(f)
        ecs.append(ec)
        if st=='6.5':
            continue
        swings.append(((swing-.5)*200).round(2))

plt.plot(times,ecs,'x', label = 'Clinton EV Prediction')
plt.plot(times,np.ones(8)*270,label='Win Threshold')
plt.xlabel('State Returns')
plt.ylabel('EVs')
plt.title('Clinton Predicted EVs Using Metropolis-Hastings Sampling and DAG Model')
plt.legend()
plt.show()

frame = pd.DataFrame(swings).T
frame.columns = times
frame
# Out:
#                Day  7 PM  7:30 PM  8 PM  8:30 PM  9 PM  10 PM  Final
# Florida      -1.62 -2.30    -3.67 -1.25    -1.25 -1.25  -1.25  -1.25
# Michigan      2.37  2.45     4.97  4.57     4.55 -0.32  -0.32  -0.32
# Pennsylvania  2.59  2.58     2.17 -0.73    -0.73 -0.73  -0.73  -0.73
# Wisconsin     5.49  4.44     5.84  5.22     5.79 -0.75  -0.75  -0.75

# %%
#MRF MH
swings = [starts]
ecs = []
times = ['Day','7 PM','7:30 PM','8 PM','8:30 PM','9 PM','10 PM','Final']
for st in ['6.5','7.0','7.5','8.0','8.5','9.0','10.0','13.0']:
    with open('data/mrf_MH_{}.pkl'.format(st), 'rb') as f:
        swing, ec = pickle.load(f)
        ecs.append(ec)
        if st=='6.5':
            continue
        swings.append(((swing-.5)*200).round(2))

plt.plot(times,ecs,'x', label = 'Clinton EV Prediction')
plt.plot(times,np.ones(8)*270,label='Win Threshold')
plt.xlabel('State Returns')
plt.ylabel('EVs')
plt.title('Clinton Predicted EVs Using Metropolis-Hastings Sampling and MRF Model')
plt.legend()
plt.show()

frame = pd.DataFrame(swings).T
frame.columns = times
frame
# Out:
#                Day  7 PM  7:30 PM  8 PM  8:30 PM  9 PM  10 PM  Final
# Florida      -1.62 -2.31    -3.88 -1.25    -1.25 -1.25  -1.25  -1.25
# Michigan      2.37  2.46     4.05  4.27     4.52 -0.32  -0.32  -0.32
# Pennsylvania  2.59  2.66     2.09 -0.73    -0.73 -0.73  -0.73  -0.73
# Wisconsin     5.49  7.08     3.58  4.82     6.31 -0.75  -0.75  -0.75

# %%
#DAG GW
swings = [starts]
ecs = []
times = ['Day','7 PM','7:30 PM','8 PM','8:30 PM','9 PM','10 PM','Final']
for st in ['6.5','7.0','7.5','8.0','8.5','9.0','10.0','13.0']:
    with open('data/dag_GW_{}.pkl'.format(st), 'rb') as f:
        swing, ec = pickle.load(f)
        ecs.append(ec)
        if st=='6.5':
            continue
        swings.append(((swing-.5)*200).round(2))

plt.plot(times,ecs,'x', label = 'Clinton EV Prediction')
plt.plot(times,np.ones(8)*270,label='Win Threshold')
plt.xlabel('State Returns')
plt.ylabel('EVs')
plt.title('Clinton Predicted EVs Using Goodman-Weare Sampling and DAG Model')
plt.legend()
plt.show()

frame = pd.DataFrame(swings).T
frame.columns = times
frame
# Out:
#                Day  7 PM  7:30 PM  8 PM  8:30 PM  9 PM  10 PM  Final
# Florida      -1.62 -1.15    -3.99 -1.25    -1.25 -1.25  -1.25  -1.25
# Michigan      2.37  2.05     4.09  4.22     3.99 -0.32  -0.32  -0.32
# Pennsylvania  2.59  1.73     1.04 -0.73    -0.73 -0.73  -0.73  -0.73
# Wisconsin     5.49  4.18     3.05  4.70     4.71 -0.75  -0.75  -0.75

# %%
#MRF GW
swings = [starts]
ecs = []
times = ['Day','7 PM','7:30 PM','8 PM','8:30 PM','9 PM','10 PM','Final']
for st in ['6.5','7.0','7.5','8.0','8.5','9.0','10.0','13.0']:
    with open('data/mrf_GW_{}.pkl'.format(st), 'rb') as f:
        swing, ec = pickle.load(f)
        ecs.append(ec)
        if st=='6.5':
            continue
        swings.append(((swing-.5)*200).round(2))

plt.plot(times,ecs,'x', label = 'Clinton EV Prediction')
plt.plot(times,np.ones(8)*270,label='Win Threshold')
plt.xlabel('State Returns')
plt.ylabel('EVs')
plt.title('Clinton Predicted EVs Using Goodman-Weare Sampling and MRF Model')
plt.legend()
plt.show()

frame = pd.DataFrame(swings).T
frame.columns = times
frame
# Out:
#                Day  7 PM  7:30 PM  8 PM  8:30 PM  9 PM  10 PM  Final
# Florida      -1.62 -0.53    -3.00 -1.25    -1.25 -1.25  -1.25  -1.25
# Michigan      2.37  2.31     4.26  4.26     4.06 -0.32  -0.32  -0.32
# Pennsylvania  2.59  1.04     1.84 -0.73    -0.73 -0.73  -0.73  -0.73
# Wisconsin     5.49  5.98     3.41  5.58     5.20 -0.75  -0.75  -0.75
